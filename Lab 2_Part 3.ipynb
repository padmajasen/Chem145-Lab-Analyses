# %%
Lab2_Part3

# %%
import numpy as np
import matplotlib.pyplot as plt
D = np.loadtxt('Part 3 2c.txt')   

ax = plt.axes()           # Create an axis
ax.plot(D[:,0],D[:,1])    # Plot the data

plt. title('Luminescence Spectrum of Spinach Extract under 405nm Illumination')
plt. xlabel('Wavelength [nm]')
plt. ylabel('Luminescence [arb.]')
# Out:
# Text(0, 0.5, 'Luminescence [arb.]')
